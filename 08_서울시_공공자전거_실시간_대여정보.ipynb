# %% [markdown]
# # **1. 서울 열린데이터 광장**
# 서울 열린데이터 광장(Seoul Open Data Plaza)은 서울시에서 운영하는 공공데이터 개방 플랫폼입니다. 시민, 연구자, 기업 등이 서울시에서 생성한 다양한 공공데이터를 자유롭게 활용할 수 있도록 제공하고 있습니다. 이를 통해 데이터 기반의 창의적인 아이디어와 혁신을 촉진하며, 시민들의 정보 접근성을 높이고 공공서비스를 개선하는 데 기여하고 있습니다.

# %% [markdown]
# # **2. 서울시 공공자전거 실시간 대여정보**
#
# 1. "서울시 공공자전거 실시간 대여정보" 를 검색합니다.
# 2. "인증키를 발급 받습니다."

# %%
import requests

# %%
base_url = "http://openapi.seoul.go.kr:8088/4c734a54726c68733634715278715a/json/bikeList/1/10/"
response = requests.get(base_url)
response
# Out:
# <Response [200]>

# %%
# Json을 문자로 변경, 딕셔너리로 저장
json_data = response.json()
json_data
# Out:
# {'rentBikeStatus': {'list_total_count': 10,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'rackTotCnt': '15',
#     'stationName': '102. 망원역 1번출구 앞',
#     'parkingBikeTotCnt': '4',
#     'shared': '27',
#     'stationLatitude': '37.55564880',
#     'stationLongitude': '126.91062927',
#     'stationId': 'ST-4'},
#    {'rackTotCnt': '14',
#     'stationName': '103. 망원역 2번출구 앞',
#     'parkingBikeTotCnt': '6',
#     'shared': '43',
#     'stationLatitude': '37.55495071',
#     'stationLongitude': '126.91083527',
#     'stationId': 'ST-5'},
#    {'rackTotCnt': '13',
#     'stationName': '104. 합정역 1번출구 앞',
#     'parkingBikeTotCnt': '8',
#     'shared': '62',
#     'stationLatitude': '37.55073929',
#     'stationLongitude': '126.91508484',
#     'stationId': 'ST-6'},
#    {'rackTotCnt': '5',
#     'stationName': '105. 합정역 5번출구 앞',
#     'parkingBikeTotCnt': '1',
#     'shared': '20',
#     'stationLatitude': '37.55000687',
#     'stationLongitude': '126.91482544',
#     'stationId': 'ST-7'},
#    {'rackTotCnt': '12',
#     'stationName': '106. 합정역 7번출구 앞',
#     'parkingBikeTotCnt': '6',
#     'shared': '50',
#     'stationLatitude': '37.54864502',
#     'stationLongitude': '126.91282654',
#     'stationId': 'ST-8'},
#    {'rackTotCnt': '10',
#     'stationName': '107. 수협 연남동지점',
#     'parkingBikeTotCnt': '1',
#     'shared': '10',
#     'stationLatitude': '37.55784607',
#     'stationLongitude': '126.91871643',
#     'stationId': 'ST-9'},
#    {'rackTotCnt': '12',
#     'stationName': '108. 서교동 사거리',
#     'parkingBikeTotCnt': '4',
#     'shared': '33',
#     'stationLatitude': '37.55274582',
#     'stationLongitude': '126.91861725',
#     'stationId': 'ST-10'},
#    {'rackTotCnt': '10',
#     'stationName': '111. 상수역 2번출구 앞',
#     'parkingBikeTotCnt': '1',
#     'shared': '10',
#     'stationLatitude': '37.54787064',
#     'stationLongitude': '126.92353058',
#     'stationId': 'ST-15'},
#    {'rackTotCnt': '28',
#     'stationName': '113. 홍대입구역 2번출구 앞',
#     'parkingBikeTotCnt': '10',
#     'shared': '36',
#     'stationLatitude': '37.55743790',
#     'stationLongitude': '126.92382050',
#     'stationId': 'ST-18'},
#    {'rackTotCnt': '15',
#     'stationName': '114. 홍대입구역 8번출구 앞',
#     'parkingBikeTotCnt': '7',
#     'shared': '47',
#     'stationLatitude': '37.55706024',
#     'stationLongitude': '126.92442322',
#     'stationId': 'ST-20'}]}}

# %%
# CODE 파싱
json_data['rentBikeStatus']['RESULT']['CODE']
# Out:
# 'INFO-000'

# %%
json_data.get('rentBikeStatus', {}).get("RESULT", {}).get('CODE', {})
# Out:
# 'INFO-000'

# %%
import requests
import pandas as pd

# %%
base_url = "http://openapi.seoul.go.kr:8088/4c734a54726c68733634715278715a/json/bikeList/1/10/"
response = requests.get(base_url)
# response
# Json을 문자로 변경, 딕셔너리로 저장
json_data = response.json()
# json_data
json_data
# Out:
# {'rentBikeStatus': {'list_total_count': 10,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'rackTotCnt': '15',
#     'stationName': '102. 망원역 1번출구 앞',
#     'parkingBikeTotCnt': '6',
#     'shared': '40',
#     'stationLatitude': '37.55564880',
#     'stationLongitude': '126.91062927',
#     'stationId': 'ST-4'},
#    {'rackTotCnt': '14',
#     'stationName': '103. 망원역 2번출구 앞',
#     'parkingBikeTotCnt': '6',
#     'shared': '43',
#     'stationLatitude': '37.55495071',
#     'stationLongitude': '126.91083527',
#     'stationId': 'ST-5'},
#    {'rackTotCnt': '13',
#     'stationName': '104. 합정역 1번출구 앞',
#     'parkingBikeTotCnt': '8',
#     'shared': '62',
#     'stationLatitude': '37.55073929',
#     'stationLongitude': '126.91508484',
#     'stationId': 'ST-6'},
#    {'rackTotCnt': '5',
#     'stationName': '105. 합정역 5번출구 앞',
#     'parkingBikeTotCnt': '2',
#     'shared': '40',
#     'stationLatitude': '37.55000687',
#     'stationLongitude': '126.91482544',
#     'stationId': 'ST-7'},
#    {'rackTotCnt': '12',
#     'stationName': '106. 합정역 7번출구 앞',
#     'parkingBikeTotCnt': '7',
#     'shared': '58',
#     'stationLatitude': '37.54864502',
#     'stationLongitude': '126.91282654',
#     'stationId': 'ST-8'},
#    {'rackTotCnt': '10',
#     'stationName': '107. 수협 연남동지점',
#     'parkingBikeTotCnt': '1',
#     'shared': '10',
#     'stationLatitude': '37.55784607',
#     'stationLongitude': '126.91871643',
#     'stationId': 'ST-9'},
#    {'rackTotCnt': '12',
#     'stationName': '108. 서교동 사거리',
#     'parkingBikeTotCnt': '6',
#     'shared': '50',
#     'stationLatitude': '37.55274582',
#     'stationLongitude': '126.91861725',
#     'stationId': 'ST-10'},
#    {'rackTotCnt': '10',
#     'stationName': '111. 상수역 2번출구 앞',
#     'parkingBikeTotCnt': '1',
#     'shared': '10',
#     'stationLatitude': '37.54787064',
#     'stationLongitude': '126.92353058',
#     'stationId': 'ST-15'},
#    {'rackTotCnt': '28',
#     'stationName': '113. 홍대입구역 2번출구 앞',
#     'parkingBikeTotCnt': '8',
#     'shared': '29',
#     'stationLatitude': '37.55743790',
#     'stationLongitude': '126.92382050',
#     'stationId': 'ST-18'},
#    {'rackTotCnt': '15',
#     'stationName': '114. 홍대입구역 8번출구 앞',
#     'parkingBikeTotCnt': '6',
#     'shared': '40',
#     'stationLatitude': '37.55706024',
#     'stationLongitude': '126.92442322',
#     'stationId': 'ST-20'}]}}

# %%
a = json_data.get('row[0]', {}).get('rackTotCnt', {})
print(a)
# Out:
# {}

# %%
def fetch_bike_data():
    base_url = "http://openapi.seoul.go.kr:8088/4c734a54726c68733634715278715a/json/bikeList/"
    start = 1
    end = 1000
    step = 1000
    data_frames = []

    while True:
        url = f'{base_url}{start}/{end}/'
        response = requests.get(url)

        if response.status_code != 200:
            print(f'status code: {response.status_code}')
            break

        json_data = response.json()

        try:
            rent_bike_status = json_data['rentBikeStatus']
            result_code = rent_bike_status['RESULT']['CODE']
        except KeyError:
            print("JSON 오류")
            break

        if result_code == 'INFO-200':
            print('데이터 없음')
            break

        elif result_code=='INFO-000':
            print(f'시작: {start} 끝: {end}')
            try:
                bike_data = rent_bike_status['row']
                if bike_data:
                    df = pd.DataFrame(bike_data)
                    data_frames.append(df)
            except KeyError:
                print("데이터를 찾을 수 없음")
        else:
            print(f'result code: {result_code}')
            break

        start += step
        end += step

    if data_frames:
        final_df = pd.concat(data_frames, ignore_index=True)
        return final_df
    else:
        return pd.DataFrame()

# %%
bike_data_df = fetch_bike_data()
bike_data_df
# Out:
# 시작: 1 끝: 1000
# 시작: 1001 끝: 2000
# 시작: 2001 끝: 3000
# JSON 오류
#      rackTotCnt            stationName parkingBikeTotCnt shared  \
# 0            15        102. 망원역 1번출구 앞                 4     27
# 1            14        103. 망원역 2번출구 앞                 5     36
# 2            13        104. 합정역 1번출구 앞                 8     62
# 3             5        105. 합정역 5번출구 앞                 1     20
# 4            12        106. 합정역 7번출구 앞                 8     67
# ...         ...                    ...               ...    ...
# 2739         12     6187.마곡119안전센터 맞은편                18    150
# 2740         17             6188.금호아파트                27    159
# 2741         11     6189.데시앙플렉스 지식산업센터                20    182
# 2742         10  6190.마곡광장(마곡나루역 6번출구)                 4     40
# 2743         10           6191.가양역5번출구                 1     10
#
#      stationLatitude stationLongitude stationId
# 0        37.55564880     126.91062927      ST-4
# 1        37.55495071     126.91083527      ST-5
# 2        37.55073929     126.91508484      ST-6
# 3        37.55000687     126.91482544      ST-7
# 4        37.54864502     126.91282654      ST-8
# ...              ...              ...       ...
# 2739     37.55534744     126.82072449   ST-3415
# 2740     37.55611038     126.86475372   ST-3419
# 2741     37.56448364     126.84830475   ST-3424
# 2742     37.56614685     126.82738495   ST-3421
# 2743     37.56021500     126.85717010   ST-3437
#
# [2744 rows x 7 columns]

# %%
import folium

# %%
bike_data_df['stationLatitude'] = bike_data_df['stationLatitude'].astype(float)
bike_data_df['stationLongitude'] = bike_data_df['stationLongitude'].astype(float)

# %%
bike_map = folium.Map(location=[bike_data_df['stationLatitude'].mean(),
                                bike_data_df['stationLongitude'].mean()],
                                zoom_start=12)

for index, data in bike_data_df.iterrows():
    popup_str = '{} 자전거 주차 총 건수:{}대'.format(
        data['stationName'], data['parkingBikeTotCnt']
    )
    popup = folium.Popup(popup_str, max_width=600)
    folium.Marker(location=[data['stationLatitude'], data['stationLongitude']],
                popup=popup).add_to(bike_map)

bike_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_624fbe39f0c9eb62ce8d9353363952ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_624fbe39f0c9eb62ce8d9353363952ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_624fbe39f0c9eb62ce8d9353363952ec = L.map(
#                 &quot;map_624fbe39f0c9eb62ce8d9353363952ec&quot;,
#                 {
#                     center: [37.54788218013484, 126.99136583305757],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_081e8fb70547e445787108c69cd0d5c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_081e8fb70547e445787108c69cd0d5c4.addTo(map_624fbe39f0c9eb62ce8d9353363952ec);
#
#
#             var marker_e67cfeffb08cfd198f83da4f0956ccef = L.marker(
#                 [37.5556488, 126.91062927],
#                 {
# }
#             ).addTo(map_624fbe39f0c9eb62ce8d9353363952ec);
#
#
#         var popup_f594abf3befc1c2426d2aca6f679e3b9 = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_a0cad733fce6cf016a7893732b361c66 = $(`&lt;div id=&quot;html_a0cad733fce6cf016a7893732b361c66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102. 망원역 1번출구 앞 자전거 주차 총 건수:4대&lt;/div&gt;`)[0];
#                 popup_f594abf3befc1c2426d2aca6f679e3b9.setContent(html_a0cad733fce6cf016a7893732b361c66);
#
#
#
#         marker_e67cfeffb08cfd198f83da4f0956ccef.bindPopup(popup_f594abf3befc1c2426d2aca6f679e3b9)
#         ;
#
#
#
#
#             var marker_e13d7557950113eb4a445707dbfe0d7f = L.marker(
#                 [37.55495071, 126.91083527],
#                 {
# }
#             ).addTo(map_624fbe39f0c9eb62ce8d9353363952ec);
#
#
#         var popup_e134a9ebfc75bfe9856e823ca6a53277 = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_e51445ba295bd2d20bd7001e3ad7d63c = $(`&lt;div id=&quot;html_e51445ba295bd2d20bd7001e3ad7d63c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103. 망원역 2번출구 앞 자전거 주차 총 건수:5대&lt;/div&gt;`)[0];
#                 popup_e134a9ebfc75bfe9856e823ca6a53277.setContent(html_e51445ba295bd2d20bd7001e3ad7d63c);
#
#
#
#         marker_e13d7557950113eb4a445707dbfe0d7f.bindPopup(popup_e134a9ebfc75bfe9856e823ca6a53277)
#         ;
#
#
#
#
#             var marker_07bcc393401a0b0ba3ab9c7d9a72f696 = L.marker(
#                 [37.55073929, 126.91508484],
#                 {
# }
#             ).addTo(map_624fbe39f0c9eb62ce8d9353363952ec);
#
#
#         var popup_95aa057e8e8497a667a166f4bd00fbdd = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_320deb87ca18968109ea63125557fe1e = $(`&lt;div id=&quot;html_320deb87ca18968109ea63125557fe1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;104. 합정역 1번출구 앞 자전거 주차 총 건수:8대&lt;/div&gt;`)[0];
#                 popup_95aa057e8e8497a667a166f4bd00fbdd.setContent(html_320deb87ca18968109ea63125557fe1e);
#
#
#
#         marker_07bcc393401a0b0ba3ab9c7d9a72f696.bindPopup(popup_95aa057e8e8497a667a166f4bd00fbdd)
#         ;
#
#
#
#
#             var marker_70a4c2bbd8c23e6803e14c340b8afc07 = L.marker(
#                 [37.55000687, 126.91482544],
#                 {
# }
#             ).addTo(map_624fbe39f0c9eb62ce8d9353363952ec);
#
#
#         var popup_25efba1eef8a52b433bddb575eb3739b = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_ca6795f381f0b7869fa8b7a00ad440c5 = $(`&lt;div id=&quot;html_ca6795f381f0b7869fa8b7a00ad440c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;105. 합정역 5번출구 앞 자전거 주차 총 건수:1대&lt;/div&gt;`)[0];
#                 popup_25efba1eef8a52b433bddb575eb3739b.setContent(html_ca6795f381f0b7869fa8b7a00ad440c5);
#
#
#
#         marker_70a4c2bbd8c23e6803e14c340b8afc07.bindPopup(popup_25efba1eef8a52b433bddb575eb3739b)
#         ;
#
#
#
#
#             var marker_d28898f108669b8c72f671af8b6c6d67 = L.marker(
#                 [37.54864502, 126.91282654],
#                 {
# }
#             ).addTo(map_624fbe39f0c9eb62ce8d9353363952ec);
#
#
#         var popup_673444a80cbcd5eb6c495a2872ae7daf = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_4159969fafddb1bbdb8f0cc7a7b0b8c9 = $(`&lt;div id=&quot;html_4159969fafddb1bbdb8f0cc7a7b0b8c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;106. 합정역 7번출구 앞 자전거 주차 총 건수:8대&lt;/div&gt;`)[0];
#                 popup_673444a80cbcd5eb6c495a2872ae7daf.setContent(html_4159969fafddb
